# %%
import pandas as pd
import numpy as np

# %%
#read in the csv
data = pd.read_csv('/Users/joshdustin/Desktop/dataflaskproject/Murder Data (2008-2014).csv', index_col='Year')

# %%
#view top five rows with header
data.head()
# Out:
#       Record ID Agency Code            Agency Name       Agency Type  \
# Year
# 2013     604373     NC06001  Charlotte-Mecklenburg  Municipal Police
# 2013     604374     NC06001  Charlotte-Mecklenburg  Municipal Police
# 2013     604375     NC06001  Charlotte-Mecklenburg  Municipal Police
# 2013     604376     NC06001  Charlotte-Mecklenburg  Municipal Police
# 2013     604377     NC06001  Charlotte-Mecklenburg  Municipal Police
#
#              City           State     Month  Incident              Crime Type  \
# Year
# 2013  Mecklenburg  North Carolina  February         3  Murder or Manslaughter
# 2013  Mecklenburg  North Carolina  February         4  Murder or Manslaughter
# 2013  Mecklenburg  North Carolina     April         1  Murder or Manslaughter
# 2013  Mecklenburg  North Carolina     April         2  Murder or Manslaughter
# 2013  Mecklenburg  North Carolina     April         3  Murder or Manslaughter
#
# ...

# %%
# %matplotlib inline
data.plot()
